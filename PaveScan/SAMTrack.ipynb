# %% [markdown]
# <a href="https://colab.research.google.com/github/meryemjabrane1/AI-Summer-School/blob/main/SAMTrack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clone the SAMTrack repository using Git

# %%
# !git clone https://github.com/z-x-yang/Segment-and-Track-Anything.git
# %cd /content/Segment-and-Track-Anything
# Out:
# Cloning into 'Segment-and-Track-Anything'...
# remote: Enumerating objects: 588, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 588 (delta 20), reused 23 (delta 15), pack-reused 547
# Receiving objects: 100% (588/588), 219.20 MiB | 41.70 MiB/s, done.
# Resolving deltas: 100% (256/256), done.
# /content/Segment-and-Track-Anything

# %% [markdown]
# # Install dependencies

# %%
# !bash script/install.sh
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/Segment-and-Track-Anything/sam
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for segment-anything
# ...
# /content/Segment-and-Track-Anything
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining GroundingDINO from git+https://github.com/IDEA-Research/GroundingDINO.git@main#egg=GroundingDINO
#   Cloning https://github.com/IDEA-Research/GroundingDINO.git (to revision main) to ./src/groundingdino
#   Running command git clone --filter=blob:none --quiet https://github.com/IDEA-Research/GroundingDINO.git /content/Segment-and-Track-Anything/src/groundingdino
#   Resolved https://github.com/IDEA-Research/GroundingDINO.git to commit a4dcf5d411366d80b36c853372753330433a871a
#   Preparing metadata (setup.py) ... done
# ...

# %% [markdown]
# # Download ckpt

# %%
# !mkdir ./ckpt
# !bash script/download_ckpt.sh
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1QoChMkTVxdYZ_eBlZhK2acq9KMQZccPJ
# To: /content/Segment-and-Track-Anything/ckpt/R50_DeAOTL_PRE_YTB_DAV.pth
# 100% 237M/237M [00:06<00:00, 36.1MB/s]
# --2023-05-03 11:34:15--  https://dl.fbaipublicfiles.com/segment_anything/sam_vit_b_01ec64.pth
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 13.249.141.9, 13.249.141.40, 13.249.141.108, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|13.249.141.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 375042383 (358M) [binary/octet-stream]
# Saving to: ‘./ckpt/sam_vit_b_01ec64.pth’
#
# sam_vit_b_01ec64.pt 100%[===================>] 357.67M   207MB/s    in 1.7s
#
# ...

# %% [markdown]
# # Run WebUI

# %%
# !pip install gradio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached gradio-3.28.1-py3-none-any.whl (17.3 MB)
# ...
#   Using cached websockets-11.0.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
# ...
#   Using cached uvicorn-0.22.0-py3-none-any.whl (58 kB)
# ...
#   Using cached fastapi-0.95.1-py3-none-any.whl (56 kB)
# ...
#   Using cached python_multipart-0.0.6-py3-none-any.whl (45 kB)
# ...
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# ...
#   Using cached orjson-3.8.11-cp310-cp310-manylinux_2_28_x86_64.whl (135 kB)
# ...
#   Using cached httpx-0.24.0-py3-none-any.whl (75 kB)
# ...
#   Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# ...
#   Using cached ffmpy-0.3.0.tar.gz (4.8 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached mdit_py_plugins-0.3.3-py3-none-any.whl (50 kB)
# ...
#   Using cached aiofiles-23.1.0-py3-none-any.whl (14 kB)
# ...

# %%
# !python app.py
# Out:
# /usr/local/lib/python3.10/dist-packages/gradio/components.py:167: UserWarning: Unknown style parameter: height
#   warnings.warn(f"Unknown style parameter: {key}")
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://1a88c18cb6f88c49e0.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# get meta information of input video
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# final text_encoder_type: bert-base-uncased
# ...
