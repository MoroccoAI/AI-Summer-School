# %%
import requests
from bs4 import BeautifulSoup
import re
import os, json

PATH = "sites.txt"
OUT_PATH = "data.json"

def scrape(url):
	print(f"Getting {url}")
	response = requests.get(url.replace('\n',''))
	html_content = response.text

	soup = BeautifulSoup(html_content, "html.parser")

	# Find the main content div using its id or class
	content_div = soup.find("div", id="mw-content-text")

	# Find all the paragraphs within the main content div
	paragraphs = content_div.find_all("p")

	out = []
	# Extract the text from the paragraphs
	for paragraph in paragraphs:
	    text = paragraph.get_text()
	    # Process and store the extracted text as desired
	    element = {'source':url,'text':text}
	    out.append(element)

	return out

if __name__ == '__main__':

	data = []
	with open(PATH) as f:
		for i in range(32):
			url = f.readline()
			data.extend(scrape(url))


	with open(OUT_PATH,'w') as out:
		json.dump(data,out,indent=2)
		print('Saved')
# Out:
# Getting https://en.wikipedia.org/wiki/Majorelle_Garden
#
# Getting https://en.wikipedia.org/wiki/Botanical_garden
#
# Getting https://en.wikipedia.org/wiki/Jacques_Majorelle
#
# Getting https://en.wikipedia.org/wiki/Yves_Saint_Laurent_(designer)
#
# Getting https://en.wikipedia.org/wiki/Pierre_Berg%C3%A9
#
# Getting https://en.wikipedia.org/wiki/Yves_Saint_Laurent_Museum_in_Marrakesh
#
# Getting https://en.wikipedia.org/wiki/Louis_Majorelle
#
# Getting https://en.wikipedia.org/wiki/Kutubiyya_Mosque
#
# Getting https://en.wikipedia.org/wiki/Almohad_Caliphate
#
# Getting https://en.wikipedia.org/wiki/Abd_al-Mu%27min
#
# Getting https://en.wikipedia.org/wiki/Almoravid_dynasty
#
# Getting https://en.wikipedia.org/wiki/Yaqub_al-Mansur
#
# Getting https://en.wikipedia.org/wiki/Moroccan_architecture
#
# Getting https://en.wikipedia.org/wiki/Jemaa_el-Fnaa
#
# Getting https://en.wikipedia.org/wiki/Kutubiyya_Mosque
#
# Getting https://en.wikipedia.org/wiki/Marrakesh
#
# Getting https://en.wikipedia.org/wiki/Abu_Bakr_ibn_Umar
#
# Getting https://en.wikipedia.org/wiki/Ben_Youssef_Madrasa
#
# Getting https://en.wikipedia.org/wiki/Ben_Youssef_Mosque
#
# Getting https://en.wikipedia.org/wiki/Saadi_Sultanate
#
# Getting https://en.wikipedia.org/wiki/Abdallah_al-Ghalib
#
# Getting https://en.wikipedia.org/wiki/Jemaa_el-Fnaa
#
# Getting https://en.wikipedia.org/wiki/Menara_gardens
#
# Getting https://en.wikipedia.org/wiki/Agdal_Gardens
#
# Getting https://en.wikipedia.org/wiki/Bab_Mansur_al-%27Alj
#
# Getting https://en.wikipedia.org/wiki/Ismail_Ibn_Sharif
#
# Getting https://en.wikipedia.org/wiki/Hassan_Tower
#
# Getting https://en.wikipedia.org/wiki/Mausoleum_of_Mohammed_V
#
# Getting https://en.wikipedia.org/wiki/Ifrane
#
# Getting https://en.wikipedia.org/wiki/University_of_al-Qarawiyyin
#
# Getting https://en.wikipedia.org/wiki/Fatima_al-Fihriya
#
# Getting https://en.wikipedia.org/wiki/Chouara_Tannery
# Saved
